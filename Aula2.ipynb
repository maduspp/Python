# %% [markdown]
# 1) Leia um valor inteiro e verifique se ele é par

# %%
numero = int(input())
if numero % 2 == 0:
  print('S')
else:
  print("N")
# Out:
# 598
# S

# %% [markdown]
# 2) As crianças estão aprendendo a desenhar a bandeira brasileira e precisam da sua ajuda. Elas sabem o nome das cores mas não sabem o nome das figuras geométricas. Seu programa deve ler o nome de uma cor e informar qual a forma geométrica correspondente.

# %%
cor = input()
if cor == 'azul':
  print('circunferência')
elif   cor == 'amarelo':
  print('losango')
elif cor == 'verde':
  print('retângulo')
elif cor == 'branco':
  print('faixa')
else:
  print('não tem essa cor')
# Out:
# rosa
# não tem essa cor

# %% [markdown]
# 3) Carros autônomos devem obedecer as mesmas regras que os motoristas humanos e, além disso, serem mais cuidadosos ainda. Por isso, quando você for fazer o programa de um carro autônomo, você vai fazer o carro avançar apenas se o semáforo estiver verde.
#
# Seu programa deve ler a cor do semáforo (verde/amarelo/vermelho) e dar o comando correto para o carro (avançar ou parar)

# %%
farol = input()

if farol == 'verde':
  print('avançar')
else:
  print('parar')
# Out:
# amarelo
# parar

# %% [markdown]
# 4) Uma pessoa está fazendo uma compra por um site Web. Ela colocou um conjunto de itens no carrinho de compras, e vai pagar a compra com PIX.
#
# Essa pessoa decidiu nunca gastar mais do ela realmente tem.
#
# Seu programa deve ler duas linhas, com um valor inteiro cada.
#
# O primeiro valor corresponde ao valor em dinheiro que a pessoa tem na conta do banco. O segundo valor corresponde ao total calculado no carrinho de compras.
#
# Seu programa deve verificar se a pessoa pode ou não realizar a compra de modo a respeitar sua própria decisão, e emitir mensagens correspondentes:
#
# se o saldo for suficiente, informar 'pode comprar tudo' caso contrário, informar 'saldo insuficiente'
# Duas linhas, com um valor inteiro cada (i.e. apenas valores inteiros)

# %%
conta = int(input())
carrinho = int(input())

if conta >= carrinho:
  print('pode comprar tudo')
else:
  print('saldo insuficiente')
# Out:
# 1234
# 234
# pode comprar tudo

# %% [markdown]
# 5) A Compra Responsável Informada
#
# Uma pessoa está fazendo uma compra por um site Web.
#
# Ela colocou um conjunto de itens no carrinho de compras, e vai pagar a compra com PIX.
#
# Essa pessoa decidiu nunca gastar mais do ela realmente tem.
#
# Seu programa deve ler duas linhas, com um valor inteiro cada.
#
# - o primeiro valor corresponde ao valor em dinheiro que a pessoa tem na conta do banco
#
# - o segundo valor corresponde ao total calculado no carrinho de compras.
#
# Seu programa deve verificar se a pessoa pode ou não realizar a compra de modo a respeitar sua própria decisão, e emitir mensagens correspondentes.
#
# Caso não deve ser efetuada para respeitar a decisão, informar 'seu saldo é insuficiente para essa compra'.

# %%
conta = int(input())
carrinho = int(input())
if conta >= carrinho:
  print('se você comprar tudo o saldo será:', conta - carrinho)
else:
  print('seu saldo é insuficiente para essa compra')
# Out:
# 700
# 500
# se você comprar tudo o saldo será: 200

# %% [markdown]
# 6) Seu programa deve ler um valor inteiro, correspondente à idade de uma pessoa, e informar se essa pessoa tem idade para votar ou ainda é jovem demais.
#
# Veja as mensagens esperadas nos exemplos.

# %%
idade = int(input())
if idade >= 16:
  print('Tem idade para votar')
else:
  print('Jovem demais para votar, espere até 16')

# %% [markdown]
# 7) Seu programa deve per um valor inteiro, correspondente à idade de uma pessoa, e informar se essa pessoa tem idade para votar e, se for, se o voto é obrigatório ou facultativo.
# Veja as mensagens esperadas no exemplos. Lembre que o voto é facultativo para quem tem 16 e 17 anos, ou para quem tem 70 anos ou mais. Entre 18 e 69 anos, o voto é obrigatório.

# %%
idade = int(input())
if idade <= 15:
  print('Jovem demais para votar, espere até 16')
elif idade == 16:
  print('Seu voto é facultativo: você pode votar ou não')
elif idade == 17:
  print('Seu voto é facultativo: você pode votar ou não')
elif idade >= 18 and idade <= 69:
  print('Seu voto é obrigatório')
if idade >= 70:
  print('Seu voto é facultativo: você pode votar ou não')
# Out:
# 84
# Seu voto é facultativo: você pode votar ou não

# %% [markdown]
# 8) Dado o número correspondente a um dos meses do ano, seu programa deve imprimir qual a abreviatura do mês correspondente.

# %%
mes = int(input())
if mes == 1:
  print('jan')
elif mes == 2:
  print('fev')
elif mes == 3:
  print('mar')
elif mes == 4:
  print('abr')
elif mes == 5:
  print('mai')
elif mes == 6:
  print('jun')
elif mes == 7:
  print('jul')
elif mes == 8:
  print('ago')
elif mes == 9:
  print('set')
elif mes == 10:
  print('out')
elif mes == 11:
  print('nov')
elif mes == 12:
  print('dez')
# Out:
# 8
# ago

# %% [markdown]
# 9) Para promover o rodízio da circulação de veículos, algumas cidades definem regras que associam o final da placa do veículo ao um dia da semana em que o veículo não deve circular.
# Alguns aplicativos permitem que você informe a placa de seu veículo e você resolveu investigar como faria isso em um programa.
# Seu programa deve ler um inteiro que corresponde aos dígitos da placa de um veículo, e verificar qual é o último dígido daquela placa.

# %%
placa = (input())
certo = placa[3]
print(certo)
# O [] serve para escrever apenas o caractere desejado. O primeiro equivale a 0. Tem que ser string.
# Out:
# 8755
# 5

# %% [markdown]
# 10)Seu programa deve ler um inteiro que corresponde ao número da placa de um veículo, e informar em qual dia da semana aquele veículo não deve circular.
#
# As regras são:
#
# > Na segunda-feira não devem circular carros com final 1 e 2
#
# > Na terça-feira não devem circular carros com final 3 e 4
#
# > Na quarta-feira não devem circular carros com final 5 e 6
#
# > Na quinta-feira não devem circular carros com final 7 e 8
#
# > Na sexta-feira não devem circular carros com final 9 e 0

# %%
placa = input()
certo = placa[3]

if certo == '1' or certo == '2':
  print('segunda-feira')
elif certo == '3' or certo == '4':
  print('terça-feira')
elif certo == '5' or certo == '6':
  print('quarta-feira')
elif certo == '7' or certo == '8':
  print('quinta-feira')
elif certo == '9' or certo == '0':
  print('sexta-feira')
# Out:
# fao2620
# segunda-feira

# %% [markdown]
# 11) Seu programa deve ler uma letra e verificar a qual algarismo romano ela corresponde.
#
# Garante-se que apenas um dos seguintes valores será fornecido como entrada: I, V, X, L, C, D, M

# %%
algarismo = input()

if algarismo == 'I':
  print(int(1))
elif algarismo == 'V':
  print(int(5))
elif algarismo == 'X':
  print(int(10))
elif algarismo == 'L':
  print(int(50))
elif algarismo == 'C':
  print(int(100))
elif algarismo == 'D':
  print(int(500))
elif algarismo == 'M':
  print(int(1000))

# %% [markdown]
# 12) Seu programa deve ler um valor inteiro, correspondente a um ano (e.g. 2023),  calcular qual o século correspondente (e.g. 21), e imprimir o valor calculado.
#
# Você deve imprimir o número do século utilizando algarismos arábicos em vez de algarismos romanos, que são normalmente utilizados nesse caso.

# %%
ano = (input())
numero = ano[0] + ano[1]
numerot = ano[0]
operacao = int(numero)
operacaot = int(numerot)
seculo = operacao + 1
seculot =
maior = 999
menor = 1000

if int(ano) > maior:
  print(seculo)
else:
  print(seculot)
# Out:
# 2101
# 22

# %% [markdown]
# 13) As teclas A S W D são parte importante de qualquer jogo que utilize o teclado.
#
# (Quase) Todo mundo sabe que elas correspondem a teclas de direção e sentido.
#
# Seu programa deve ler um valor correspondente a uma tecla (como uma string normal, ou seja, usando diretamente o resultado da função input())
#
# A seguir, seu programa deve identificar se o valor lido corresponde uma das teclas A S W D,  que podem ser digitadas com letra minúsculas ou maiúsculas.
#
# Se for uma dessas teclas, informar qual é, em inglês e sempre em letras maísculas (veja os exemplos)
#
# Se nao for, seu programa informa um ponto de interrogação

# %%
tecla = input()
if tecla == 'A' or tecla == 'a':
  print('LEFT')
elif tecla == 'W' or tecla == 'w':
  print('UP')
elif tecla == 'D' or tecla == 'd':
  print('RIGHT')
elif tecla == 'S' or tecla == 's':
  print('DOWN')
else:
  print('?')
# Out:
# l
# ?

# %% [markdown]
# 14) Seu programa deve ler três linhas. Na primeira, um símbolo correspondendo a uma operação entre dois inteiros. Nas linhas seguintes, um valor inteiro cada. O programa deve calcular o resultado da operação entre os dois inteiros e imprimir o resultado.

# %%
simbolo = input()
a = int(input())
b = int(input())
if simbolo == '+':
  print(a + b)
elif simbolo == '-':
  print(a - b)
elif simbolo == '*':
  print(a * b)
elif simbolo == '**':
  print(a ** b)
elif simbolo == '/':
  print(a / b)
elif simbolo == '//':
  print(a // b)
elif simbolo == '%':
  print(a % b)
# Out:
# +
# 1234
# 4321
# 5555

# %% [markdown]
# 15)
# Um jogo de vôlei é disputado em uma sequência de sets. Um set normalmente termina em 25 pontos mas. Entretanto, em caso de empate em 24 pontos, o set só terminará quando uma equipe alcançar uma diferença de 2 pontos em relação à outra equipe: nesse caso, não há ponto limite para o término do set.
#
# S ou N, no caso de o set ter encerrado com pontuação mínima ou não, respectivamente

# %%
a = int(input())
b = int(input())

if a > (b + 2) or b > (a + 2):
  print('S')
else:
  print("N")
# Out:
# 14
# 13
# N

# %% [markdown]
# 16) Dados dois valores inteiros, sua tarefa é identificar quem é o maior e quem é o menor

# %%
um = int((input()))
dois = int((input()))

if um < dois:
  print('maior:', dois)
  print('menor:', um)
else:
  print('maior:', um)
  print('menor:', dois)
# Out:
# 100
# -10
# maior: 100
# menor: -10

# %% [markdown]
# 17) O Maior e o Menor entre 3

# %%
um = int(input())
dois = int(input())
tres = int(input())

if um > dois and um > tres:
  print('maior:', um)
elif dois > um and dois > tres:
  print('maior:', dois)
elif tres > um and tres > dois:
  print('maior:', tres)
if um < dois and um < tres:
  print('menor:', um)
elif dois < um and dois < tres:
  print('menor:', dois)
elif tres < um and tres < dois:
  print('menor:', tres)
# Out:
# 35
# 22
# 11
# maior: 35
# menor: 11

# %%
um = int(input())
dois = int(input())
tres = int(input())

if um > dois and um > tres:
  print('maior:', um)
elif dois > um and dois > tres:
  print('maior:', dois)
elif tres > um and tres > dois:
  print('maior:', tres)
if um < dois and um < tres:
  print('menor:', um)
elif dois < um and dois < tres:
  print('menor:', dois)
elif tres < um and tres < dois:
  print('menor:', tres)

# %% [markdown]
# 18) Dada uma string, ela está contida em outra?

# %%
parte = input()
frase = input()

if parte in frase:
  print(parte, 'in', frase)
else:
  print(parte, 'not in', frase)
# Out:
# meninas
# meninas indas
# meninas in meninas indas

# %% [markdown]
# 19) Dado um caractere qual sua classidicacao?
# vogal, algarismo, especial ou outro?

# %%
vogais = 'aeiouAEIOU'
algarismo = '0123456789'
especial = '@#$%&*()_-+=!'
entrada = input()
if entrada in vogais:
  print('vogal')
elif entrada in algarismo:
  print('algarismo')
elif entrada in especial:
  print('especial')
else:
  print('outro')
# Out:
# E
# vogal

# %% [markdown]
# 20) Contido ou nao contido?

# %%
***um = input()
dois = input()
tres = input()

if um in dois and um in tres:
  print(um, 'CONTIDO EM', dois, "E", um, 'CONTIDO EM', tres)
elif um in dois and um not in tres:
    print(um, 'CONTIDO EM', dois, "MAS", um, 'NÂO CONTIDO EM', tres)
elif um not in dois and um in tres:
  print(um, 'NÂO CONTIDO EM', dois, "MAS", um, 'CONTIDO EM', tres)
elif um not in dois and um not in tres:
    print(um, 'NÂO CONTIDO EM', dois, "E", um, 'NÂO CONTIDO EM', tres)
