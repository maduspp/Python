# %% [markdown]
# ***Exercício*** 1)
# No parque ecológico de São Carlos há um papagaienengraçado. Ele adora aprender palavras novas, mas sempre as repete duas vezes.  As crianças de divertem demais!
# Seu programa deve imitar o papagaio engraçado >:-)

# %%
mensagem = input()
print(mensagem)
print(mensagem)
# Out:
# meninas
# meninas
# meninas

# %% [markdown]
# **Exercício** 2) Seu programa deve ler três informações sobre um animal e imprimir uma mensagem que descreve o animal com base nessas informações, como ilustrado nos exemplos

# %%
nome = input()
atributo = input()
acao = input()
print(("Um"), nome, ("tem"), atributo, ("e pode"), acao)
# Out:
# gato
# bigode
# miar
# Um gato tem bigode e pode miar

# %% [markdown]
# ***Exercício 3***

# %%
#exemplo
a = input()
b = input()

resultado = a + b

print(a, '+', b, '=', resultado)
# Out:
# 1
# 2
# 1 + 2 = 12

# %% [markdown]
# Seu programa deve ler três strings quaisquer e imprimir a soma dessas strings duas a duas, em todas as ordens possíveis. A ordem da impressão é a mesma ordem na qual as strings foram dadas, como nos exemplos.

# %%
a = input()
b = input()
c = input()

u = a + b
v = a + c
w = b + a
x = b + c
y = c + a
z = c + b

print (u)
print (v)
print (w)
print (x)
print (y)
print (z)
# Out:
# madu
# eduarda
# duda
# madueduarda
# madududa
# eduardamadu
# eduardaduda
# dudamadu
# dudaeduarda

# %% [markdown]
# ***Exercício 4***

# %%
#teste e exemplo do exercício
sequencia_de_caracteres = input()
print(sequencia_de_caracteres + sequencia_de_caracteres)
print(sequencia_de_caracteres, sequencia_de_caracteres)
print('[', sequencia_de_caracteres, ']')

# %% [markdown]
# Seu programa deve ler um nome oferecido como entrada e imprimir uma mensagem de boas vindas como saída

# %%
nome = input()
print('Bem-vinda',nome)
# Out:
# Madu
# Bem-vinda Madu

# %% [markdown]
# ***Exercício 5)*** Neste exercício, sua tarefa é fazer um programa vai imprimir o nome completo de uma pessoa, anexando o nome ao sobrenome

# %%
nome = input()
sobrenome = input()
print(nome, sobrenome)
# Out:
# Eduarda
# Araujo
# Eduarda Araujo

# %% [markdown]
# ***Exercício 6)*** Seu programa deve ler um inteiro, calcular o próximo valor inteiro, e imprimir o valor calculado.

# %%
valor = int(input())
print(valor +  1)
# Out:
# 5
# 6

# %% [markdown]
# ***Exercício 7)*** Seu programa deve ser um inteiro, calcular o valor inteiro anterior, e imprimir o valor calculado.

# %%
valor = int(input())
print(valor -  1)
# Out:
# 6
# 5

# %% [markdown]
# ***Exercício 8)*** Seu programa deve ser um inteiro, calcular o dobro do valor lido, e imprimir o valor calculado.

# %%
valor = int(input())
print(valor * 2)
# Out:
# 101
# 202

# %% [markdown]
# ***Exercício 9)***Seu programa deve ser um inteiro, calcular a metade do valor lido, e imprimir o valor calculado.

# %%
valor = int(input())
print(valor / 2)
# Out:
# 18
# 9.0

# %% [markdown]
# ***Exercício 10)***   Seu programa deve ler dois valores inteiros, um em cada linha, e calcular:
#
# o resultado da divisão inteira do primeiro pelo segundo e
# o resultado do resto da divisão inteira do primeiro pelo segundo
# e imprimir os valores calculados.

# %%
a = int(input())
b = int(input())
resultado = a // b
resto = a % b
print(resultado)
print(resto)
# Out:
# 10101010
# 2
# 5050505
# 0

# %% [markdown]
# ***Exercício 11)*** Seu programa deve ler dois valores, nome e idade, e imprimi-los na ordem inversa, diminuindo a idade em dois anos :-)

# %%
nome = input()
idade = int(input())
print(idade - 2)
print(nome)
# Out:
# madu
# 18
# 16
# madu

# %% [markdown]
# ***Exercício 12)*** Todo mundo sabe que não se deve colocar data de aniversário como PIN, certo? Só que é uma pena, porque é tão mais fácil de lembrar do que valores arbitrários.
# Por conta disso, você bolou uma estratégia para gerar um código de quatro dígitos: em vez de colocar direto o ano de aniversário de alguém, você soma os anos de datas importantes para você (por exemplo, ano em que fez 16 anos e tirou seu título de leitor, e ano em que entrou na faculdade).

# %%
data = int(input())
ano = int(input())
print(data + ano)
# Out:
# 2005
# 2021
# 4026

# %% [markdown]
# ***Exercício 13)*** Uma pessoa está fazendo uma compra por um site Web. Ela colocou um conjunto de itens no carrinho de compras, e vai pagar a compra com PIX. Essa pessoa tem cheque especial na conta, o que significa que ela pode gastar mais do que realmente tem mas vai pagar juros absurdos por isso.
#
# Seu programa deve ler duas linhas, com um valor inteiro cada. O primeiro valor corresponde ao valor em dinheiro que a pessoa tem na conta do banco. O segundo valor corresponde ao total calculado no carrinho de compras. Seu programa deve calcular qual o saldo na conta depois que a pessoa pagar a conta com PIX.

# %%
conta = int(input())
carrinho = int(input())
print(conta - carrinho)
# Out:
# 500
# 250
# 250

# %% [markdown]
# ***Exercício 14)*** Seu programa deve ler duas linhas, com um valor inteiro cada. O primeiro valor corresponde ao salário de uma pessoa. O segundo valor corresponde à porcentagem de aumento que deve ser adicionada ao salário. Seu programa deve calcular o valor correspondente ao aumento do salário informado, quando aplicada a porcentagem informada, e imprimir o valor calculado.

# %%
salario = int(input())
aumento = int(input())
resultado = (aumento / 100) * salario
print(resultado)
# Out:
# 1234
# 1
# 12.34

# %% [markdown]
# ***Exercício 15)*** Seu programa deve ler duas linhas, com um valor inteiro cada. O primeiro valor corresponde ao salário de uma pessoa. O segundo valor corresponde à porcentagem de aumento que deve ser adicionada ao salário. Seu programa deve calcular o novo salário, e imprimir o valor calculado.#

# %%
salario = int(input())
aumento = int(input())
resultado = (aumento / 100) * salario
print(resultado + salario)
# Out:
# 320
# 6
# 339.2

# %% [markdown]
# ***Exercício 16)*** Seu programa deve ler um valor com casas decimais e apresentá-lo com 2, 4, 6, 8 e 10 casas decimais.

# %%
valor = float(input())
print('%.2f' % valor)
print('%.4f' % valor)
print('%.6f' % valor)
print('%.8f' % valor)
print('%.10f' % valor)
# Out:
# 3.1415926536
# 3.14
# 3.1416
# 3.141593
# 3.14159265
# 3.1415926536

# %% [markdown]
# ***Exercício 17)***  Dados o total de uma conta (valor decimal) e a porcentagem escolhida pelo cliente para a gorjeta (valor inteiro), calcule o valor final da conta (com duas casas decimais)

# %%
valor = float(input())
porcentagem = int(input())
y = (valor + (porcentagem /100) * valor)
print('%.2f' % y)
# Out:
# 1.10
# 10
# 1.21

# %% [markdown]
# ***Exercício*** 18) Quantos minutos de monitoria você fez?
# Ajude os monitores a calcularem quantos minutos de monitoria você fez, a partir do número de horas e minutos que você participou.

# %%
horas = int(input())
minutos = int(input())
um = horas * 60
print(um + minutos)

# %% [markdown]
# Exercício 19) Dado um número de minutos, seu programa deve calcular os números de horas e de minutos correspondentes.

# %%
inicial = int(input())
hora = (inicial // 60)
minutos = (inicial % 60)
print(str(inicial) + 'min' + ' = ' + str(hora) + 'h' + str(minutos) + 'min')
# Out:
# 99
# 99min = 1h39min

# %% [markdown]
# ***Exercício 20**** Usar as equivalências acima para apresentar em mililitros os valores das receitas que você e outras pessoas vão usar na creche.
# uma xícara equivale a 240 ml
#
# uma colher de sopa equivale a 15 ml
#
# uma colher de chá equivale a 5 ml

# %%
xicaras = int(input())
cs = int(input())
cc = int(input())
um = xicaras * 240
dois = cs * 15
tres = cc * 5
print(um, 'ml')
print(dois, 'ml')
print(tres, 'ml')
# Out:
# 1
# 2
# 3
# 240 ml
# 30 ml
# 15 ml

# %% [markdown]
# ***Exercício 21)*** Dados as notas em cada área obtidas por uma candidata mas provas do ENEM, e os pesos de cada área, apresente o total de pontos correspondentes.

# %%
um = int(input())
dois = int(input())
tres = int(input())
quatro = int(input())
cinco = int(input())
pesou = int(input())
pesod = int(input())
pesot = int(input())
pesoq = int(input())
pesoc =int(input())
a = (um * pesou)
b = (dois * pesod)
c = (tres * pesot)
d = (quatro * pesoq)
e = (cinco * pesoc)
tp = (pesou + pesod + pesot + pesoq + pesoc)
tn = (a + b + c + d + e)
print(tn / tp)
# Out:
# 760
# 800
# 640
# 720
# 1000
# 4
# 4
# 2
# 2
# 4
# 810.0
